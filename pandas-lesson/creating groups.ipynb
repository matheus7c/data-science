# %% [markdown]
# # Report VII

# %% [markdown]
# ## Creating groups

# %%
import pandas as pd

# %%
dados = pd.read_csv('data/aluguel_residencial.csv', sep = ';')

# %%
dados.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento         Cachambi        2      0       0    50
# 6       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 7       Casa de Condomínio            Ramos        2      2       0    65
# 8  Conjunto Comercial/Sala           Centro        0      3       0   695
# 9              Apartamento           Grajaú        2      1       0    70
#
#      Valor  Condominio    IPTU  Valor m2 Tipo Agregado
# 0   1700.0       500.0    60.0     42.50   Apartamento
# 1   7000.0         0.0     0.0     70.00          Casa
# 2   5200.0      4020.0  1111.0     34.67   Apartamento
# 3    800.0       390.0    20.0     53.33   Apartamento
# 4    800.0       230.0     0.0     16.67   Apartamento
# 5   1300.0       301.0    17.0     26.00   Apartamento
# 6  22000.0         0.0     0.0     29.33          Casa
# 7   1000.0         0.0     0.0     15.38          Casa
# 8  35000.0     19193.0  3030.0     50.36   Apartamento
# 9   1500.0       642.0    74.0     21.43   Apartamento

# %%
dados['Valor'].mean()
# Out:
# 13177.971364681036

# %%
bairros = ['Barra da Tijuca', 'Copacabana', 'Ipanema', 'Leblon', 'Botafogo', 'Flamengo', 'Tijuca']
selecao = dados['Bairro'].isin(bairros)
dados = dados[selecao]
dados
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                    Quitinete       Copacabana        1      0       0    40
# 2      Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 6           Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 11                 Apartamento       Copacabana        1      0       1    40
# 12                   Quitinete       Copacabana        1      0       0    27
# ...                        ...              ...      ...    ...     ...   ...
# 32185              Apartamento           Leblon        3      0       1    80
# 32187              Apartamento          Ipanema        3      1       2   150
# 32188              Apartamento           Tijuca        1      0       0    28
# 32190       Casa de Condomínio  Barra da Tijuca        5      3       4   450
# 32196              Apartamento           Leblon        2      0       0    70
#
#          Valor  Condominio    IPTU  Valor m2 Tipo Agregado
# 0       1700.0       500.0    60.0     42.50   Apartamento
# 2       5200.0      4020.0  1111.0     34.67   Apartamento
# 6      22000.0         0.0     0.0     29.33          Casa
# 11      2000.0       561.0    50.0     50.00   Apartamento
# 12      1800.0       501.0     0.0     66.67   Apartamento
# ...        ...         ...     ...       ...           ...
# 32185   3000.0      1010.0   249.0     37.50   Apartamento
# 32187  15000.0      1400.0   600.0    100.00   Apartamento
# 32188   1000.0       360.0    25.0     35.71   Apartamento
# 32190  15000.0      1711.0  2332.0     33.33          Casa
# 32196   3000.0       760.0     0.0     42.86   Apartamento
#
# [16429 rows x 11 columns]

# %%
grupo_bairro = dados.groupby('Bairro')

# %%
dados['Bairro'].drop_duplicates()
# Out:
# 0           Copacabana
# 2      Barra da Tijuca
# 14            Botafogo
# 19              Tijuca
# 23              Leblon
# 25             Ipanema
# 107           Flamengo
# Name: Bairro, dtype: object

# %%
grupo_bairro.groups
# Out:
# {'Barra da Tijuca': [2, 6, 18, 20, 28, 33, 39, 42, 47, 57, 58, 75, 78, 86, 87, 90, 94, 100, 101, 108, 109, 111, 130, 142, 151, 152, 153, 154, 155, 159, 161, 163, 167, 171, 174, 187, 191, 193, 197, 219, 222, 224, 241, 242, 245, 249, 253, 254, 266, 268, 272, 296, 305, 315, 320, 322, 330, 337, 338, 344, 348, 354, 358, 364, 377, 380, 389, 391, 397, 405, 408, 423, 429, 430, 431, 433, 441, 444, 445, 454, 459, 460, 482, 488, 494, 498, 501, 502, 511, 519, 533, 535, 543, 547, 555, 562, 570, 572, 573, 578, ...], 'Botafogo': [14, 15, 30, 64, 80, 112, 120, 121, 160, 177, 186, 195, 198, 232, 283, 287, 324, 350, 366, 413, 447, 458, 479, 496, 534, 537, 611, 612, 640, 658, 726, 730, 766, 770, 795, 833, 866, 877, 892, 930, 959, 1014, 1062, 1080, 1117, 1127, 1138, 1153, 1168, 1215, 1223, 1242, 1268, 1349, 1356, 1364, 1369, 1378, 1462, 1473, 1478, 1526, 1573, 1591, 1613, 1622, 1637, 1658, 1689, 1716, 1752, 1756, 1757, 1783, 1826, 1870, 1877, 1889, 1902, 1925, 1969, 1998, 2025, 2033, 2055, 2080, 2089, 2114, 2152, 2213, 2242, 2255, 2331, 2352, 2398, 2405, 2425, 2441, 2468, 2494, ...], 'Copacabana': [0, 11, 12, 13, 31, 32, 37, 41, 56, 119, 128, 148, 158, 184, 190, 203, 204, 207, 209, 213, 220, 237, 244, 255, 265, 276, 281, 293, 319, 361, 388, 407, 410, 415, 427, 428, 442, 453, 468, 473, 475, 485, 490, 514, 530, 542, 552, 553, 571, 585, 597, 624, 625, 632, 638, 641, 667, 670, 680, 711, 712, 713, 714, 728, 739, 776, 779, 783, 807, 821, 841, 842, 849, 858, 867, 895, 899, 901, 907, 934, 936, 961, 980, 987, 988, 993, 1004, 1017, 1020, 1026, 1036, 1053, 1079, 1089, 1094, 1137, 1146, 1179, 1194, 1206, ...], 'Flamengo': [107, 200, 311, 312, 420, 476, 513, 526, 532, 536, 548, 577, 617, 629, 648, 697, 740, 794, 854, 915, 994, 1025, 1075, 1126, 1175, 1262, 1303, 1311, 1327, 1375, 1391, 1426, 1528, 1599, 1620, 1638, 1655, 1720, 1762, 1801, 1811, 1993, 2049, 2053, 2227, 2237, 2251, 2267, 2281, 2292, 2335, 2363, 2366, 2480, 2502, 2561, 2587, 2590, 2705, 2725, 2770, 2862, 2910, 2962, 2971, 3007, 3217, 3277, 3290, 3344, 3356, 3414, 3440, 3459, 3480, 3503, 3531, 3583, 3633, 3751, 3754, 3768, 3773, 3817, 3865, 3911, 3913, 3937, 4041, 4050, 4056, 4142, 4151, 4276, 4287, 4307, 4367, 4391, 4415, 4444, ...], 'Ipanema': [25, 53, 54, 61, 69, 71, 99, 117, 129, 165, 179, 189, 206, 229, 258, 260, 307, 310, 332, 352, 356, 398, 419, 470, 484, 497, 504, 507, 550, 559, 569, 576, 583, 589, 598, 650, 698, 705, 716, 754, 765, 784, 827, 830, 844, 847, 850, 852, 871, 873, 905, 920, 924, 957, 958, 974, 989, 996, 1010, 1021, 1037, 1046, 1050, 1060, 1067, 1073, 1078, 1081, 1085, 1105, 1106, 1113, 1118, 1147, 1151, 1170, 1185, 1188, 1196, 1199, 1200, 1207, 1227, 1266, 1267, 1289, 1305, 1322, 1326, 1333, 1336, 1363, 1368, 1377, 1383, 1405, 1407, 1430, 1432, 1447, ...], 'Leblon': [23, 35, 85, 127, 135, 168, 194, 205, 231, 243, 251, 303, 313, 321, 333, 360, 463, 465, 480, 520, 521, 579, 584, 600, 616, 649, 654, 669, 676, 683, 687, 707, 717, 725, 737, 748, 759, 800, 846, 881, 883, 890, 942, 946, 978, 1016, 1028, 1032, 1040, 1051, 1086, 1108, 1141, 1152, 1211, 1225, 1232, 1233, 1241, 1246, 1276, 1285, 1325, 1341, 1373, 1376, 1395, 1415, 1422, 1444, 1542, 1548, 1559, 1560, 1562, 1568, 1587, 1589, 1604, 1624, 1661, 1677, 1684, 1690, 1739, 1755, 1759, 1769, 1772, 1779, 1804, 1865, 1867, 1872, 1898, 1900, 1951, 1954, 1967, 2008, ...], 'Tijuca': [19, 22, 26, 110, 114, 170, 185, 188, 201, 212, 216, 218, 228, 240, 257, 261, 263, 267, 284, 289, 378, 382, 411, 503, 508, 523, 539, 642, 657, 686, 701, 729, 743, 752, 772, 824, 829, 869, 882, 886, 923, 939, 940, 968, 999, 1005, 1091, 1098, 1099, 1124, 1143, 1159, 1166, 1173, 1180, 1197, 1239, 1244, 1258, 1280, 1286, 1297, 1302, 1309, 1321, 1359, 1365, 1400, 1427, 1436, 1451, 1454, 1496, 1510, 1519, 1550, 1583, 1626, 1708, 1712, 1718, 1749, 1834, 1846, 1864, 2014, 2060, 2084, 2088, 2095, 2106, 2115, 2149, 2150, 2154, 2185, 2256, 2264, 2305, 2307, ...]}

# %%
for bairro, dados in grupo_bairro: 
    print(bairro)
# Out:
# Barra da Tijuca
# Botafogo
# Copacabana
# Flamengo
# Ipanema
# Leblon
# Tijuca

# %%
for bairro, dados in grupo_bairro: 
    print(dados)
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 2      Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 6           Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 18                 Apartamento  Barra da Tijuca        2      1       1    67
# 20          Casa de Condomínio  Barra da Tijuca        4      3       2   466
# 28                 Apartamento  Barra da Tijuca        3      3       1   175
# ...                        ...              ...      ...    ...     ...   ...
# 32178              Apartamento  Barra da Tijuca        2      1       1    85
# 32179              Apartamento  Barra da Tijuca        3      2       0    98
# 32180  Conjunto Comercial/Sala  Barra da Tijuca        0      1       0    55
# 32181              Apartamento  Barra da Tijuca        3      2       2   140
# 32190       Casa de Condomínio  Barra da Tijuca        5      3       4   450
#
#          Valor  Condominio    IPTU  Valor m2 Tipo Agregado
# 2       5200.0      4020.0  1111.0     34.67   Apartamento
# 6      22000.0         0.0     0.0     29.33          Casa
# 18      1700.0       589.0   147.0     25.37   Apartamento
# 20      7500.0      2695.0     0.0     16.09          Casa
# 28      4200.0      1500.0   500.0     24.00   Apartamento
# ...        ...         ...     ...       ...           ...
# 32178   2250.0      1561.0   197.0     26.47   Apartamento
# 32179   2300.0       887.0   177.0     23.47   Apartamento
# 32180   2000.0      1096.0     0.0     36.36   Apartamento
# 32181   5500.0      1900.0   700.0     39.29   Apartamento
# 32190  15000.0      1711.0  2332.0     33.33          Casa
#
# [6198 rows x 11 columns]
#                           Tipo    Bairro  Quartos  Vagas  Suites  Area  \
# 14              Prédio Inteiro  Botafogo        0      0       0   536
# 15                        Flat  Botafogo        3      1       1    80
# 30                 Apartamento  Botafogo        2      1       0    76
# 64                 Apartamento  Botafogo        3      1       1   108
# 80              Casa Comercial  Botafogo        0      0       0   140
# ...                        ...       ...      ...    ...     ...   ...
# 32042              Apartamento  Botafogo        2      1       1    52
# 32080              Apartamento  Botafogo        2      1       2    84
# 32122  Conjunto Comercial/Sala  Botafogo        0     18       0   958
# 32127  Conjunto Comercial/Sala  Botafogo        0      8       0   467
# 32145              Apartamento  Botafogo        3      2       1   100
#
#          Valor  Condominio    IPTU  Valor m2 Tipo Agregado
# 14     28000.0         0.0  3563.0     52.24   Apartamento
# 15      3800.0      1040.0     0.0     47.50   Apartamento
# 30      2500.0       740.0     0.0     32.89   Apartamento
# 64      5950.0      1405.0   289.0     55.09   Apartamento
# 80      7000.0         0.0   137.0     50.00   Apartamento
# ...        ...         ...     ...       ...           ...
# 32042   3100.0      1700.0   330.0     59.62   Apartamento
# 32080   4230.0      1130.0   260.0     50.36   Apartamento
# 32122  95784.0     29698.0  5509.0     99.98   Apartamento
# 32127  53730.0     14796.0  2728.0    115.05   Apartamento
# 32145   4500.0      1600.0   205.0     45.00   Apartamento
#
# [1356 rows x 11 columns]
#               Tipo      Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0        Quitinete  Copacabana        1      0       0    40   1700.0
# 11     Apartamento  Copacabana        1      0       1    40   2000.0
# 12       Quitinete  Copacabana        1      0       0    27   1800.0
# 13     Apartamento  Copacabana        4      3       1   243  13000.0
# 31     Apartamento  Copacabana        3      1       2   378  10000.0
# ...            ...         ...      ...    ...     ...   ...      ...
# 32138  Apartamento  Copacabana        1      0       0    60   2400.0
# 32154  Apartamento  Copacabana        2      0       0    67   2450.0
# 32174  Apartamento  Copacabana        2      0       1    70   4100.0
# 32176  Apartamento  Copacabana        1      0       0    50   1950.0
# 32183    Quitinete  Copacabana        1      0       0    22   1500.0
#
#        Condominio   IPTU  Valor m2 Tipo Agregado
# 0           500.0   60.0     42.50   Apartamento
# 11          561.0   50.0     50.00   Apartamento
# 12          501.0    0.0     66.67   Apartamento
# 13         2000.0  803.0     53.50   Apartamento
# 31         2150.0  700.0     26.46   Apartamento
# ...           ...    ...       ...           ...
# 32138       530.0   78.0     40.00   Apartamento
# 32154       679.0   80.0     36.57   Apartamento
# 32174       700.0   90.0     58.57   Apartamento
# 32176       450.0   70.0     39.00   Apartamento
# 32183       286.0  200.0     68.18   Apartamento
#
# [3070 rows x 11 columns]
#                           Tipo    Bairro  Quartos  Vagas  Suites  Area  \
# 107                  Quitinete  Flamengo        0      0       0    28
# 200                Apartamento  Flamengo        1      0       0    40
# 311    Conjunto Comercial/Sala  Flamengo        0      0       0    32
# 312                Apartamento  Flamengo        1      1       0    48
# 420                Apartamento  Flamengo        2      0       0    85
# ...                        ...       ...      ...    ...     ...   ...
# 32024              Apartamento  Flamengo        2      0       0    77
# 32056                Quitinete  Flamengo        1      0       0    23
# 32059              Apartamento  Flamengo        3      1       0   169
# 32068              Apartamento  Flamengo        3      0       1   115
# 32153              Apartamento  Flamengo        1      0       0    48
#
#         Valor  Condominio    IPTU  Valor m2 Tipo Agregado
# 107    1000.0       581.0    53.0     35.71   Apartamento
# 200    1900.0       430.0    54.0     47.50   Apartamento
# 311    1300.0       400.0     0.0     40.62   Apartamento
# 312    2100.0       580.0    70.0     43.75   Apartamento
# 420    2700.0       800.0  1150.0     31.76   Apartamento
# ...       ...         ...     ...       ...           ...
# 32024  1700.0       900.0   131.0     22.08   Apartamento
# 32056   900.0       605.0     0.0     39.13   Apartamento
# 32059  5200.0      1584.0   386.0     30.77   Apartamento
# 32068  3500.0       970.0   130.0     30.43   Apartamento
# 32153  2200.0       478.0     0.0     45.83   Apartamento
#
# [803 rows x 11 columns]
#                           Tipo   Bairro  Quartos  Vagas  Suites  Area  \
# 25                 Apartamento  Ipanema        3      1       1   125
# 53                 Apartamento  Ipanema        1      0       0    35
# 54                 Apartamento  Ipanema        1      0       0    38
# 61                 Apartamento  Ipanema        3      1       0    87
# 69                 Apartamento  Ipanema        3      2       1   150
# ...                        ...      ...      ...    ...     ...   ...
# 32094              Apartamento  Ipanema        3      1       1   140
# 32133  Conjunto Comercial/Sala  Ipanema        0      0       0    26
# 32143              Apartamento  Ipanema        3      1       1   118
# 32156              Apartamento  Ipanema        1      0       0    55
# 32187              Apartamento  Ipanema        3      1       2   150
#
#          Valor  Condominio   IPTU  Valor m2 Tipo Agregado
# 25      7000.0      2100.0  463.0     56.00   Apartamento
# 53      2000.0       650.0   75.0     57.14   Apartamento
# 54      1400.0       530.0   77.0     36.84   Apartamento
# 61      3200.0      1305.0  217.0     36.78   Apartamento
# 69      8000.0      2400.0    0.0     53.33   Apartamento
# ...        ...         ...    ...       ...           ...
# 32094   7200.0      2900.0  850.0     51.43   Apartamento
# 32133   1300.0       740.0  200.0     50.00   Apartamento
# 32143   6000.0       980.0  250.0     50.85   Apartamento
# 32156   2000.0       630.0   19.0     36.36   Apartamento
# 32187  15000.0      1400.0  600.0    100.00   Apartamento
#
# [2197 rows x 11 columns]
#               Tipo  Bairro  Quartos  Vagas  Suites  Area    Valor  Condominio  \
# 23            Flat  Leblon        1      0       0    56   4500.0      1900.0
# 35     Apartamento  Leblon        3      1       0   110   3900.0      1500.0
# 85     Apartamento  Leblon        2      1       1    80   3500.0       990.0
# 127    Apartamento  Leblon        3      2       1   147   7500.0      1028.0
# 135    Apartamento  Leblon        3      1       0    85   3900.0       800.0
# ...            ...     ...      ...    ...     ...   ...      ...         ...
# 32142  Apartamento  Leblon        4      3       2   280  10000.0      3315.0
# 32166   Loja/Salão  Leblon        0      0       0    68  25000.0         0.0
# 32173  Apartamento  Leblon        1      1       1    50   4300.0      1730.0
# 32185  Apartamento  Leblon        3      0       1    80   3000.0      1010.0
# 32196  Apartamento  Leblon        2      0       0    70   3000.0       760.0
#
#          IPTU  Valor m2 Tipo Agregado
# 23     1500.0     80.36   Apartamento
# 35      120.0     35.45   Apartamento
# 85      245.0     43.75   Apartamento
# 127     247.0     51.02   Apartamento
# 135    1211.0     45.88   Apartamento
# ...       ...       ...           ...
# 32142   770.0     35.71   Apartamento
# 32166  1113.0    367.65   Apartamento
# 32173   259.0     86.00   Apartamento
# 32185   249.0     37.50   Apartamento
# 32196     0.0     42.86   Apartamento
#
# [1459 rows x 11 columns]
#               Tipo  Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 19     Apartamento  Tijuca        2      1       0   110  1900.0       700.0
# 22     Apartamento  Tijuca        2      1       0    78  2000.0       700.0
# 26     Apartamento  Tijuca        1      0       0    48   750.0       772.0
# 110    Apartamento  Tijuca        2      1       0    80  1800.0      1100.0
# 114    Apartamento  Tijuca        3      1       0   172  2700.0       780.0
# ...            ...     ...      ...    ...     ...   ...     ...         ...
# 31981  Apartamento  Tijuca        2      1       0    78  1800.0       620.0
# 32039  Apartamento  Tijuca        2      0       0    69  1700.0       760.0
# 32057  Apartamento  Tijuca        2      3       0    70  1680.0       230.0
# 32116  Apartamento  Tijuca        3      1       0    75  1900.0       860.0
# 32188  Apartamento  Tijuca        1      0       0    28  1000.0       360.0
#
#         IPTU  Valor m2 Tipo Agregado
# 19     138.0     17.27   Apartamento
# 22       0.0     25.64   Apartamento
# 26      25.0     15.62   Apartamento
# 110     84.0     22.50   Apartamento
# 114    170.0     15.70   Apartamento
# ...      ...       ...           ...
# 31981   62.0     23.08   Apartamento
# 32039   62.0     24.64   Apartamento
# 32057   45.0     24.00   Apartamento
# 32116  141.0     25.33   Apartamento
# 32188   25.0     35.71   Apartamento
#
# [1346 rows x 11 columns]

# %%
for bairro, data in grupo_bairro: 
    print('{} -> {}'.format(bairro, data.Valor.mean()))
# Out:
# Barra da Tijuca -> 9035.204743465634
# Botafogo -> 19709.716814159292
# Copacabana -> 4514.538436482085
# Flamengo -> 6923.498132004981
# Ipanema -> 10455.031861629495
# Leblon -> 11072.38930774503
# Tijuca -> 2964.5705794947994

# %%
grupo_bairro['Valor'].mean().round(2)
# Out:
# Bairro
# Barra da Tijuca     9035.20
# Botafogo           19709.72
# Copacabana          4514.54
# Flamengo            6923.50
# Ipanema            10455.03
# Leblon             11072.39
# Tijuca              2964.57
# Name: Valor, dtype: float64

# %%
grupo_bairro[['Valor', 'Condominio']].mean().round(2)
# Out:
#                     Valor  Condominio
# Bairro
# Barra da Tijuca   9035.20     3490.42
# Botafogo         19709.72     2814.36
# Copacabana        4514.54     1183.24
# Flamengo          6923.50     1890.19
# Ipanema          10455.03     2282.16
# Leblon           11072.39     2246.48
# Tijuca            2964.57      792.07

# %% [markdown]
# # descriptive statistics

# %%
grupo_bairro['Valor'].describe().round(2)
# Out:
#                   count      mean        std    min     25%     50%      75%  \
# Bairro
# Barra da Tijuca  6198.0   9035.20   30328.23  100.0  2000.0  3500.0   8000.0
# Botafogo         1356.0  19709.72  129879.42  299.0  2500.0  4000.0  11000.0
# Copacabana       3070.0   4514.54    6502.57  100.0  1900.0  3000.0   4900.0
# Flamengo          803.0   6923.50   15848.59  200.0  1900.0  3000.0   5300.0
# Ipanema          2197.0  10455.03   21002.14  100.0  4000.0  6900.0  12000.0
# Leblon           1459.0  11072.39   20830.80  100.0  4500.0  7000.0  11900.0
# Tijuca           1346.0   2964.57    8017.45  320.0  1400.0  1800.0   2500.0
#
#                        max
# Bairro
# Barra da Tijuca   738197.0
# Botafogo         4500000.0
# Copacabana        198000.0
# Flamengo          212544.0
# Ipanema           800000.0
# Leblon            430000.0
# Tijuca            230000.0

# %%
grupo_bairro['Valor'].aggregate(['min', 'max', 'sum'])
# Out:
#                    min        max         sum
# Bairro
# Barra da Tijuca  100.0   738197.0  56000199.0
# Botafogo         299.0  4500000.0  26726376.0
# Copacabana       100.0   198000.0  13859633.0
# Flamengo         200.0   212544.0   5559569.0
# Ipanema          100.0   800000.0  22969705.0
# Leblon           100.0   430000.0  16154616.0
# Tijuca           320.0   230000.0   3990312.0

# %%
grupo_bairro['Valor'].aggregate(['min', 'max']).rename(columns = {'min': 'Mínimo', 'max': 'Máximo'})
# Out:
#                  Mínimo     Máximo
# Bairro
# Barra da Tijuca   100.0   738197.0
# Botafogo          299.0  4500000.0
# Copacabana        100.0   198000.0
# Flamengo          200.0   212544.0
# Ipanema           100.0   800000.0
# Leblon            100.0   430000.0
# Tijuca            320.0   230000.0

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc('figure', figsize = (20,10))

# %%
grupo_bairro['Valor'].std().plot.bar(color = 'blue')
# Out:
# <AxesSubplot:xlabel='Bairro'>

# %%
fig = grupo_bairro['Valor'].mean().plot.bar(color = 'blue')
fig.set_ylabel('Valor do Aluguel')
fig.set_title('Valor Médio do Aluguel por Bairro', {'fontsize': 22})
# Out:
# Text(0.5, 1.0, 'Valor Médio do Aluguel por Bairro')

# %%
fig = grupo_bairro['Valor'].max().plot.bar(color = 'blue')
fig.set_ylabel('Valor do Aluguel')
fig.set_title('Valor Médio do Aluguel por Bairro', {'fontsize': 22})
# Out:
# Text(0.5, 1.0, 'Valor Médio do Aluguel por Bairro')
